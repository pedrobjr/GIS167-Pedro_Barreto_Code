# %%
first_name = Joe
Last_name = Shmoe
age = 45
miles = 3.5
action = jumped
yelled = weeeee
my paragragh = f"Yesterday morning {first_name} {last_name} went on a run to celebrate his {age}th birthday. {first_name} ran {miles}\ and {action} over a dog and shouted {yelled}!
print(my paragraph)
# Out:
#   Cell In[2], line 7
#     my paragragh = f"Yesterday morning {first_name} {last_name} went on a run to celebrate his {age}th birthday. {first_name} ran {miles}\ and {action} over a dog and shouted {yelled}!
#        ^
# SyntaxError: invalid syntax
