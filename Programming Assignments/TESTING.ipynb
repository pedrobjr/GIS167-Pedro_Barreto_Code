# %%
first = ['Mike','Joe','Carlos','Jake','Maria','Alice','Lori','Eva','Kate','Luke']
last = ['Smith','Johnson','Myers','Kruger','Mann','Chase','Grana','Clark','Williams','Jacobs']
products = ['glasses','cruches','fan','cup','desk','ipod','phone','lamp','tv','drill']
print(f'Length of first name list: {len(first)}\
\nLength of last name list: {len(last)}\
\nLength of products list: {len(products)}')
for name in range(len(first)):
    print(f'{first[name]} {last[name]}: {products[name]}\n{first[name].lower()}.{last[name].lower()}@redlands.edu\
    \nDear {first[name]} {last[name]}, I have the following item available for sale: {products[name]}.\nIf you are interested please email me.\n')
sorted_products = sorted(products)
for name in sorted_products[:4]:
    print(name.upper())
# Out:
# Length of first name list: 10
# Length of last name list: 10
# Length of products list: 10
# Mike Smith: glasses
# mike.smith@redlands.edu
# Dear Mike Smith, I have the following item available for sale: glasses.
# If you are interested please email me.
#
# Joe Johnson: cruches
# joe.johnson@redlands.edu
# Dear Joe Johnson, I have the following item available for sale: cruches.
# If you are interested please email me.
#
# Carlos Myers: fan
# carlos.myers@redlands.edu
# Dear Carlos Myers, I have the following item available for sale: fan.
# If you are interested please email me.
#
# Jake Kruger: cup
# jake.kruger@redlands.edu
# Dear Jake Kruger, I have the following item available for sale: cup.
# If you are interested please email me.
#
# Maria Mann: desk
# maria.mann@redlands.edu
# Dear Maria Mann, I have the following item available for sale: desk.
# If you are interested please email me.
#
# Alice Chase: ipod
# alice.chase@redlands.edu
# Dear Alice Chase, I have the following item available for sale: ipod.
# If you are interested please email me.
#
# Lori Grana: phone
# lori.grana@redlands.edu
# Dear Lori Grana, I have the following item available for sale: phone.
# If you are interested please email me.
#
# Eva Clark: lamp
# eva.clark@redlands.edu
# Dear Eva Clark, I have the following item available for sale: lamp.
# If you are interested please email me.
#
# Kate Williams: tv
# kate.williams@redlands.edu
# Dear Kate Williams, I have the following item available for sale: tv.
# If you are interested please email me.
#
# Luke Jacobs: drill
# luke.jacobs@redlands.edu
# Dear Luke Jacobs, I have the following item available for sale: drill.
# If you are interested please email me.
#
# CRUCHES
# CUP
# DESK
# DRILL
